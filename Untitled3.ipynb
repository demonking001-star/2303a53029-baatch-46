# %%
import numpy as np
from queue import Queue

# %%
graph = {
    0: [1,2,3],
    1: [0,2],
    2: [0,1,3,5],
    3: [0,2,4],
    4: [3,5,7],
    5: [2,7,9],
    6: [7,8],
    7: [6,8],
    8: [],
}
print("The adjacency list represting the graph is:")
print(graph)
# Out:
# The adjacency list represting the graph is:
# {0: [1, 2, 3], 1: [0, 2], 2: [0, 1, 3, 5], 3: [0, 2, 4], 4: [3, 5, 7], 5: [2, 7, 9], 6: [7, 8], 7: [6, 8], 8: []}
